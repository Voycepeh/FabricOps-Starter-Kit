# %% [markdown]
# # 04_gov_agreement_dataset_table renamed
#
# This compatibility template has moved to `04_gov_dataset_table.ipynb`. The v1.0.0 governance workflow is table-scoped, selects from `METADATA_DATA_CATALOGUE`, and no longer requires `widget_select_agreement`, `get_selected_agreement`, `agreement_id`, or `contract_version`.
